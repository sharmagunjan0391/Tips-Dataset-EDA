# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries are working!")
# Out:
# All libraries are working!

# %%
df = pd.read_csv("tips.csv")
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.shape
# Out:
# (244, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    str
#  3   smoker            244 non-null    str
#  4   day               244 non-null    str
#  5   time              244 non-null    str
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    str
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    str
# dtypes: float64(3), int64(2), str(6)
# memory usage: 21.1 KB

# %%
df.dtypes
# Out:
# total_bill          float64
# tip                 float64
# sex                     str
# smoker                  str
# day                     str
# time                    str
# size                  int64
# price_per_person    float64
# Payer Name              str
# CC Number             int64
# Payment ID              str
# dtype: object

# %%
df.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, price_per_person, Payer Name, CC Number, Payment ID]
# Index: []

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
# Find categorical columns
categorical_cols = df.select_dtypes(include='object').columns

# Show unique values for each categorical column
for col in categorical_cols:
    print(f"\n{col}:")
    print(df[col].unique())
# Out:
# sex:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# smoker:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# day:
# <StringArray>
# ['Sun', 'Sat', 'Thur', 'Fri']
# Length: 4, dtype: str
#
# time:
# <StringArray>
# ['Dinner', 'Lunch']
# Length: 2, dtype: str
#
# Payer Name:
# <StringArray>
# ['Christy Cunningham',     'Douglas Tucker',     'Travis Walters',
#    'Nathaniel Harris',       'Tonya Carter',         'Erik Smith',
#  'Kristopher Johnson',        'Robert Buck',    'Joseph Mcdonald',
#       'Jerome Abbott',
#  ...
#       'Tracy Douglas',      'Sean Gonzalez',      'Matthew Myers',
#        'Thomas Brown',     'Kimberly Crane',      'Michael Avila',
#      'Monica Sanders',         'Keith Wong',       'Dennis Dixon',
#     'Michelle Hardin']
# Length: 244, dtype: str
#
# Payment ID:
# <StringArray>
# ['Sun2959', 'Sun4608', 'Sun4458', 'Sun5260', 'Sun2251', 'Sun9679', 'Sun5985',
#  'Sun8157', 'Sun6820', 'Sun3775',
#  ...
# ...

# %%
df[['total_bill','tip']].agg(['min','max','mean','median'])
# Out:
#         total_bill        tip
# min       3.070000   1.000000
# max      50.810000  10.000000
# mean     19.785943   2.998279
# median   17.795000   2.900000

# %%
print(df['sex'].value_counts())
print(df['sex'].value_counts(normalize=True)* 100)
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# sex
# Male      64.344262
# Female    35.655738
# Name: proportion, dtype: float64

# %%
print(df['smoker'].value_counts())
print(df['smoker'].value_counts(normalize=True) * 100)
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64
# smoker
# No     61.885246
# Yes    38.114754
# Name: proportion, dtype: float64

# %%
# Highest number of transactions per day
print(df['day'].value_counts())
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
# Highest total sales (sum of total_bill) per day
print(df.groupby('day')['total_bill'].sum().sort_values(ascending=False))
# Out:
# day
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33
# Fri      325.88
# Name: total_bill, dtype: float64

# %%
# Average total_bill and tip per day
print(df.groupby('day')[['total_bill','tip']].mean().sort_values(by='total_bill',ascending=False))
# Out:
#       total_bill       tip
# day
# Sun    21.410000  3.255132
# Sat    20.441379  2.993103
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737

# %%
# Compare average total_bill and tip by smoker status
print(df.groupby('smoker')[['total_bill','tip']].mean())
# Out:
#         total_bill       tip
# smoker
# No       19.188278  2.991854
# Yes      20.756344  3.008710

# %%
# Compare average total_bill and tip by gender
print(df.groupby('sex')[['total_bill','tip']].mean())
# Out:
#         total_bill       tip
# sex
# Female   18.056897  2.833448
# Male     20.744076  3.089618

# %%
# Compare average total_bill and tip by meal time
print(df.groupby('time')[['total_bill','tip']].mean())
# Out:
#         total_bill       tip
# time
# Dinner   20.797159  3.102670
# Lunch    17.168676  2.728088

# %%
# Group by all four categories and find the highest average tip
print(df.groupby(['sex','smoker','day','time'])['tip'].mean().reset_index().sort_values(by='tip', ascending=False))
# Out:
#        sex smoker   day    time       tip
# 18    Male    Yes   Sun  Dinner  3.521333
# 9   Female    Yes   Sun  Dinner  3.500000
# 3   Female     No   Sun  Dinner  3.329286
# 12    Male     No   Sat  Dinner  3.256563
# 0   Female     No   Fri  Dinner  3.250000
# 15    Male    Yes   Fri  Dinner  3.246000
# 13    Male     No   Sun  Dinner  3.115349
# 19    Male    Yes  Thur   Lunch  3.058000
# 1   Female     No   Fri   Lunch  3.000000
# 4   Female     No  Thur  Dinner  3.000000
# 10  Female    Yes  Thur   Lunch  2.990000
# 14    Male     No  Thur   Lunch  2.941500
# 17    Male    Yes   Sat  Dinner  2.879259
# 8   Female    Yes   Sat  Dinner  2.868667
# 2   Female     No   Sat  Dinner  2.724615
# 6   Female    Yes   Fri  Dinner  2.700000
# 7   Female    Yes   Fri   Lunch  2.660000
# 11    Male     No   Fri  Dinner  2.500000
# 5   Female     No  Thur   Lunch  2.437083
# 16    Male    Yes   Fri   Lunch  1.900000

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(8, 6))
sns.histplot(df['total_bill'], bins= 20, color = 'skyblue', edgecolor = 'white')

plt.title("Distributions of Total Bills ", fontsize = 14, fontweight= 'bold')
plt.xlabel("Total Bill ($)", fontsize = 12)
plt.ylabel("Frequency", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(df['total_bill'], color='darkblue', fill=True, linewidth=2)

plt.title('Density Distribution of Total Bills (KDE)', fontsize=14, fontweight='bold')
plt.xlabel('Total Bill ($)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %%
sns.set_theme(style="whitegrid")

# Create a figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Histogram
sns.histplot(df['tip'], bins=15, color='coral', edgecolor='black', ax=axes[0])
axes[0].set_title('Histogram of Tips', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Tip Amount ($)')
axes[0].set_ylabel('Frequency')

# 2. KDE Plot
sns.kdeplot(df['tip'], color='darkred', fill=True, linewidth=2, ax=axes[1])
axes[1].set_title('KDE Plot of Tips', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Tip Amount ($)')
axes[1].set_ylabel('Density')

# 3. Combo Plot (Histogram + KDE)
sns.histplot(df['tip'], kde=True, bins=15, color='crimson', edgecolor='black', ax=axes[2])
axes[2].set_title('Histogram + KDE Overlay', fontsize=12, fontweight='bold')
axes[2].set_xlabel('Tip Amount ($)')
axes[2].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

# Create Boxplot for total_bill
plt.Figure(figsize=(8,6))
sns.boxplot(
    x=df['total_bill'],
    color= 'mediumseagreen',
    flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 8}
)

plt.title('Boxplot of Total bill', fontsize = 14, fontweight= 'bold')
plt.xlabel('Total Bill ($)', fontsize = 12)
plt.show()

# %%
sns.set_theme(style="whitegrid")

# Create Boxplot for tips
plt.figure(figsize=(8, 4))
sns.boxplot(
    x=df['tip'], 
    color='coral', 
    flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 8}
)

plt.title('Boxplot of Tips (Outlier Detection)', fontsize=14, fontweight='bold')
plt.xlabel('Tip Amount ($)', fontsize=12)
plt.show()

# %%
sns.countplot(x='size', data=df, color = 'skyblue')

plt.title('Distribution of Party Size')
plt.xlabel('Party Size')
plt.ylabel('Count')
plt.show()

# %%
day_counts = df["day"].value_counts()
busiest_day = day_counts.idxmax()
highest_count = day_counts.max()

plt.figure(figsize=(9, 5))

ax = sns.countplot(
    data=df,
    x="day",
    order=day_counts.index,
    color= 'lightblue'
)

for container in ax.containers:
    ax.bar_label(container, fontsize=11, fontweight="bold")

plt.title(
    f" Busiest Dining Day: {busiest_day} ({highest_count} transactions)",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Day")
plt.ylabel("Transactions")
plt.grid(axis="y", linestyle="--", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(data=df, x='time', hue='time', legend=False)

plt.title('Distribution of Transactions: Lunch vs Dinner', fontsize=14)
plt.xlabel('Meal Time')
plt.ylabel('Number of Transactions')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(data=df, x='smoker', hue='smoker', legend=False)

plt.title('Distribution of Transactions: Smokers vs Non-Smokers', fontsize=14)
plt.xlabel('Smoking Status')
plt.ylabel('Number of Transactions')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

ax = sns.countplot(data=df, x='sex', hue='sex', legend=False)

for container in ax.containers:
    ax.bar_label(container, fontsize=11)

plt.title('Gender Distribution of Customers', fontsize=14)
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.tight_layout()
plt.show()

# %%
# Calculate total bill for each day
day_bill = df.groupby('day')['total_bill'].sum().sort_values(ascending=False)

# Create barplot
plt.figure(figsize=(8, 5))

sns.barplot(
    x=day_bill.index,
    y=day_bill.values,
    palette='viridis',
    hue=day_bill.index,
    legend=False
)

plt.title('Total Bill Generated by Day', fontsize=14, fontweight='bold')
plt.xlabel('Day')
plt.ylabel('Total Bill ($)')

# Add values on top of bars
for i, value in enumerate(day_bill.values):
    plt.text(
        i, value + 50,
        f'${value:,.0f}',
        ha='center',
        fontweight='bold'
    )

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x='day',
    y='total_bill',
    estimator='mean',
    errorbar=None,
    color='skyblue'
)

plt.title('Average Total Bill by Day')
plt.xlabel('Day')
plt.ylabel('Average Total Bill')
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x='day',
    y='tip',
    estimator='mean',
    errorbar=None,
    color='lightgreen'
)

plt.title('Average Tip by Day')
plt.xlabel('Day')
plt.ylabel('Average Tip')
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x='day',
    y='total_bill',
    hue='smoker',
    estimator='mean',
    errorbar=None,
    palette='Set2'
)

plt.title('Average Total Bill: Smokers vs Non-Smokers')
plt.xlabel('Day')
plt.ylabel('Average Total Bill')
plt.legend(title='Smoker')
plt.show()

# %%
plt.figure(figsize=(9, 6))

sns.regplot(
    data=df,
    x="total_bill",
    y="tip",
    scatter_kws={
        "color": "purple",
        "alpha": 0.6,
        "s": 60
    },
    line_kws={
        "color": "red",
        "linewidth": 2
    }
)

plt.title("Relationship Between Total Bill and Tip", fontsize=16)
plt.xlabel("Total Bill ($)", fontsize=12)
plt.ylabel("Tip ($)", fontsize=12)
plt.grid(alpha=0.2)

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="size",
    y="total_bill",
    hue="day",
    palette="viridis",
    s=100,
    alpha=0.75
)

plt.title("Party Size vs Total Bill", fontsize=16, fontweight="bold")
plt.xlabel("Party Size")
plt.ylabel("Total Bill ($)")
plt.legend(title="Day")
plt.grid(alpha=0.2)
plt.show()

# %%
# Select numerical columns
numeric_df = df.select_dtypes(include="number")

# Calculate correlation
correlation = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(9, 6))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    square=True
)

plt.title("Correlation Between Numerical Variables", fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="day",
    y="total_bill",
    hue="time",
    palette="Set2"
)

plt.title("Total Bill Variation by Day and Time", fontsize=15)
plt.xlabel("Day")
plt.ylabel("Total Bill ($)")
plt.legend(title="Meal Time")
plt.grid(axis="y", linestyle="--", alpha=0.3)

plt.show()

# %%
# Create JointGrid
g = sns.JointGrid(
    data=df,
    x="total_bill",
    y="tip",
    hue="time",
    palette="Set2"
)

# Scatterplot
g.plot_joint(
    sns.scatterplot,
    alpha=0.7,
    s=70
)

# Add regression lines separately
for time, color in zip(["Lunch", "Dinner"], sns.color_palette("Set2", 2)):
    data = df[df["time"] == time]
    
    sns.regplot(
        data=data,
        x="total_bill",
        y="tip",
        scatter=False,
        color=color,
        ax=g.ax_joint
    )

# Marginal distributions
g.plot_marginals(
    sns.histplot,
    kde=True,
    alpha=0.4
)

# Title
g.fig.suptitle(
    "Total Bill vs Tip: Lunch vs Dinner",
    y=1.02,
    fontsize=15,
    fontweight="bold"
)

plt.show()

# %%
sns.catplot(
    data=df,
    x="day",
    y="tip",
    hue="sex",
    kind="bar",
    palette="Set2",
    errorbar=None
)

plt.title("Average Tip by Day and Gender")
plt.xlabel("Day")
plt.ylabel("Average Tip")

plt.show()

# %%
sns.lmplot(
    data=df,
    x="total_bill",
    y="tip",
    hue="smoker",
    palette="Set1",
    height=6,
    aspect=1.2,
    scatter_kws={"alpha": 0.7, "s": 60}
)

plt.title("Total Bill vs Tip by Smoking Status")
plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.show()

# %%
sns.pairplot(
    df,
    vars=["total_bill", "tip", "size"],
    hue="smoker",
    palette="Set2",
    diag_kind="kde",
    plot_kws={"alpha": 0.7, "s": 50}
)

plt.suptitle(
    "Relationships Between Numerical Variables",
    y=1.02,
    fontsize=15,
    fontweight="bold"
)

plt.show()
